# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# Database connection string (update these as per your MySQL setup)
db_user = 'root'
db_password = ''
db_host = 'localhost'
db_port = '3306'
db_name = 'saurabh'
table_name = 'comp'

# SQLAlchemy engine
engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# Path to folder with all Excel files
folder_path = '.'

# Read and combine all Excel files
combined_df = pd.DataFrame()
for file in os.listdir(folder_path):
    if file.endswith('.xlsx') or file.endswith('.xls'):
        df = pd.read_excel(os.path.join(folder_path, file), engine='openpyxl')
        combined_df = pd.concat([combined_df, df], ignore_index=True)

# Push to MySQL (append mode)
combined_df.to_sql(name=table_name, con=engine, if_exists='append', index=False)

print("✅ All Excel data pushed successfully to MySQL!")
# Out:
# ✅ All Excel data pushed successfully to MySQL!

# %%
import pandas as pd
import os

# Use current directory
folder_path = '.'

# Create an empty list to store DataFrames
all_dataframes = []

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx') or filename.endswith('.xls'):
        # Skip the output file if re-running the script
        if filename == 'combined_output.xlsx':
            continue

        file_path = os.path.join(folder_path, filename)
        try:
            df = pd.read_excel(file_path)
            all_dataframes.append(df)
        except Exception as e:
            print(f"Error reading {filename}: {e}")

# Combine all DataFrames into one
combined_df = pd.concat(all_dataframes, ignore_index=True)

# Export the combined DataFrame to a new Excel file
output_path = os.path.join(folder_path, 'combined_output.xlsx')
combined_df.to_excel(output_path, index=False)

print(f"All Excel files combined into: {output_path}")

# %%
# Bulk-load many Excel files (same header) into MySQL using LOAD DATA LOCAL INFILE.
# Works from a notebook or a .py file placed in the same folder as the Excel files.

import os, sys, tempfile, traceback
from pathlib import Path
import pandas as pd
import pymysql
from xlsx2csv import Xlsx2csv

# ========= EDIT DB CREDS =========
DB = {
    "host": "localhost",
    "user": "root",
    "password": "",
    "database": "saurabh",
    "port": 3306,
}
TABLE = "comp"
# =================================

# Options
RECURSIVE = False          # set True to include subfolders
TRUNCATE_BEFORE_LOAD = False  # set True if you want to empty the table first

EXCEL_EXTS = {".xlsx", ".xls"}


def _base_dir():
    # Use the script's folder if __file__ exists, else current working dir (Jupyter)
    try:
        return Path(__file__).parent.resolve()
    except NameError:
        return Path.cwd().resolve()


def list_excels(folder: Path, recursive: bool = False):
    it = folder.rglob("*") if recursive else folder.iterdir()
    for p in it:
        if p.is_file() and p.suffix.lower() in EXCEL_EXTS:
            yield p.resolve()


def read_header_from_excel(path: Path):
    # Fast header-only read
    df = pd.read_excel(path, nrows=0, engine=None)
    return list(df.columns)


def ensure_table(conn, table: str, columns: list[str]):
    cols_sql = ", ".join([f"`{c}` TEXT NULL" for c in columns])
    sql = f"""CREATE TABLE IF NOT EXISTS `{table}` (
        {cols_sql}
    ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4;"""
    with conn.cursor() as cur:
        cur.execute(sql)
    conn.commit()


def maybe_truncate(conn, table: str):
    with conn.cursor() as cur:
        cur.execute(f"TRUNCATE TABLE `{table}`;")
    conn.commit()


def xlsx_to_csv(xlsx_path: Path, csv_path: Path):
    # Stream conversion (low memory)
    Xlsx2csv(str(xlsx_path), outputencoding="utf-8").convert(
        str(csv_path), sheetid=1, skip_empty_lines=True
    )


def xls_to_csv(xls_path: Path, csv_path: Path):
    # Legacy .xls through pandas (loads in memory per file)
    df = pd.read_excel(xls_path, engine=None)
    df.to_csv(csv_path, index=False)


def load_csv(conn, csv_path: Path, table: str, columns: list[str]):
    cols = ", ".join(f"`{c}`" for c in columns)
    sql = f"""
    LOAD DATA LOCAL INFILE %s
    INTO TABLE `{table}`
    CHARACTER SET utf8mb4
    FIELDS TERMINATED BY ',' ENCLOSED BY '"' ESCAPED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES
    ({cols});
    """
    with conn.cursor() as cur:
        # Use absolute path string for client-side LOCAL upload
        cur.execute(sql, (str(csv_path),))
    conn.commit()


def main():
    base = _base_dir()
    print(f"📂 Base folder: {base}")

    files = sorted(list(list_excels(base, RECURSIVE)))
    print(f"Found {len(files)} Excel file(s).")
    if not files:
        return

    # Header from first file
    print("Reading header from first file...")
    base_header = read_header_from_excel(files[0])
    if not base_header:
        print("Could not read header from first Excel.")
        return
    print(f"Columns ({len(base_header)}): {base_header}")

    # Connect with LOCAL INFILE enabled
    conn = pymysql.connect(local_infile=True, **DB)
    try:
        with conn.cursor() as cur:
            try:
                cur.execute("SET GLOBAL local_infile=1;")
            except Exception:
                pass
            cur.execute("SET SESSION local_infile=1;")
            cur.execute("SET SESSION sql_mode='';")
            cur.execute("SET SESSION foreign_key_checks=0;")
            cur.execute("SET SESSION unique_checks=0;")
        conn.commit()

        ensure_table(conn, TABLE, base_header)
        if TRUNCATE_BEFORE_LOAD:
            print(f"Truncating `{TABLE}`...")
            maybe_truncate(conn, TABLE)

        total = len(files)
        loaded = 0
        skipped = 0

        print(f"🚀 Importing into `{TABLE}` ...")
        for i, f in enumerate(files, 1):
            try:
                # Validate header equality per file
                fh = read_header_from_excel(f)
                if fh != base_header:
                    print(f"[{i}/{total}] SKIP (header mismatch): {f.name}")
                    skipped += 1
                    continue

                # Convert to temp CSV
                with tempfile.NamedTemporaryFile(prefix="xl2csv_", suffix=".csv", delete=False) as tmp:
                    csv_path = Path(tmp.name)

                if f.suffix.lower() == ".xlsx":
                    xlsx_to_csv(f, csv_path)
                else:
                    xls_to_csv(f, csv_path)

                # Load CSV
                load_csv(conn, csv_path, TABLE, base_header)

                # Cleanup
                try:
                    csv_path.unlink(missing_ok=True)
                except Exception:
                    pass

                loaded += 1
                print(f"[{i}/{total}] Loaded: {f.name}")

            except Exception as e:
                print(f"[{i}/{total}] FAILED: {f.name}")
                traceback.print_exc()

        print(f"✅ Done. Loaded {loaded}, skipped {skipped}, total {total}.")

        # Quick count (optional)
        try:
            with conn.cursor() as cur:
                cur.execute(f"SELECT COUNT(*) FROM `{TABLE}`;")
                cnt = cur.fetchone()[0]
            print(f"Rows now in `{TABLE}`: {cnt}")
        except Exception:
            pass

    finally:
        conn.close()


# Run immediately (works in notebooks too)
main()

# %%
# Bulk-load many Excel files (same header) into MySQL using LOAD DATA LOCAL INFILE.
# Works from a notebook or a .py file placed in the same folder as the Excel files.

import os, sys, tempfile, traceback
from pathlib import Path
import pandas as pd
import pymysql
from xlsx2csv import Xlsx2csv

# ========= EDIT DB CREDS =========
DB = {
    "host": "localhost",
    "user": "root",
    "password": "",
    "database": "saurabh",
    "port": 3306,
}
TABLE = "comp"
# =================================

# Options
RECURSIVE = False              # set True to include subfolders
TRUNCATE_BEFORE_LOAD = False   # set True if you want to empty the table first

EXCEL_EXTS = {".xlsx", ".xls"}


def _base_dir():
    # Use the script's folder if __file__ exists, else current working dir (Jupyter)
    try:
        return Path(__file__).parent.resolve()
    except NameError:
        return Path.cwd().resolve()


def list_excels(folder: Path, recursive: bool = False):
    it = folder.rglob("*") if recursive else folder.iterdir()
    for p in it:
        if p.is_file() and p.suffix.lower() in EXCEL_EXTS:
            yield p.resolve()


def read_header_from_excel(path: Path):
    # Fast header-only read
    df = pd.read_excel(path, nrows=0, engine=None)
    return list(df.columns)


def ensure_table(conn, table: str, columns: list[str]):
    cols_sql = ", ".join([f"`{c}` TEXT NULL" for c in columns])
    sql = f"""CREATE TABLE IF NOT EXISTS `{table}` (
        {cols_sql}
    ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4;"""
    with conn.cursor() as cur:
        cur.execute(sql)
    conn.commit()


def maybe_truncate(conn, table: str):
    with conn.cursor() as cur:
        cur.execute(f"TRUNCATE TABLE `{table}`;")
    conn.commit()


def xlsx_to_csv(xlsx_path: Path, csv_path: Path):
    # Stream conversion (low memory)
    Xlsx2csv(str(xlsx_path), outputencoding="utf-8").convert(
        str(csv_path), sheetid=1, skip_empty_lines=True
    )


def xls_to_csv(xls_path: Path, csv_path: Path):
    # Legacy .xls through pandas (loads in memory per file)
    df = pd.read_excel(xls_path, engine=None)
    df.to_csv(csv_path, index=False)


def load_csv(conn, csv_path: Path, table: str, columns: list[str]):
    cols = ", ".join(f"`{c}`" for c in columns)
    sql = f"""
    LOAD DATA LOCAL INFILE %s
    INTO TABLE `{table}`
    CHARACTER SET utf8mb4
    FIELDS TERMINATED BY ',' ENCLOSED BY '"' ESCAPED BY '"'
    LINES TERMINATED BY '\\n'
    IGNORE 1 LINES
    ({cols});
    """
    with conn.cursor() as cur:
        cur.execute(sql, (str(csv_path),))
    conn.commit()


def main():
    base = _base_dir()
    print(f"📂 Base folder: {base}")

    files = sorted(list(list_excels(base, RECURSIVE)))
    print(f"Found {len(files)} Excel file(s).")
    if not files:
        return

    # Header from first file
    print("Reading header from first file...")
    base_header = read_header_from_excel(files[0])
    if not base_header:
        print("Could not read header from first Excel.")
        return
    print(f"Columns ({len(base_header)}): {base_header}")

    # Connect with LOCAL INFILE enabled on client side
    conn = pymysql.connect(local_infile=True, **DB)
    try:
        with conn.cursor() as cur:
            # Try to enable globally if you have privileges; OK if it fails.
            try:
                cur.execute("SET GLOBAL local_infile=1;")
            except Exception:
                pass

            # DO NOT set SESSION local_infile here; it's global-only on your server
            # Safe tweaks:
            try:
                cur.execute("SET SESSION sql_mode='';")
            except Exception:
                pass
            try:
                cur.execute("SET SESSION foreign_key_checks=0;")
            except Exception:
                pass
            try:
                cur.execute("SET SESSION unique_checks=0;")
            except Exception:
                pass

            # Show current effective value for visibility
            try:
                cur.execute("SHOW GLOBAL VARIABLES LIKE 'local_infile';")
                print("local_infile:", cur.fetchone())
            except Exception:
                pass

        conn.commit()

        ensure_table(conn, TABLE, base_header)
        if TRUNCATE_BEFORE_LOAD:
            print(f"Truncating `{TABLE}`...")
            maybe_truncate(conn, TABLE)

        total = len(files)
        loaded = 0
        skipped = 0

        print(f"🚀 Importing into `{TABLE}` ...")
        for i, f in enumerate(files, 1):
            try:
                # Validate header equality per file
                fh = read_header_from_excel(f)
                if fh != base_header:
                    print(f"[{i}/{total}] SKIP (header mismatch): {f.name}")
                    skipped += 1
                    continue

                # Convert to temp CSV
                with tempfile.NamedTemporaryFile(prefix="xl2csv_", suffix=".csv", delete=False) as tmp:
                    csv_path = Path(tmp.name)

                if f.suffix.lower() == ".xlsx":
                    xlsx_to_csv(f, csv_path)
                else:
                    xls_to_csv(f, csv_path)

                # Load CSV
                load_csv(conn, csv_path, TABLE, base_header)

                # Cleanup
                try:
                    csv_path.unlink(missing_ok=True)
                except Exception:
                    pass

                loaded += 1
                print(f"[{i}/{total}] Loaded: {f.name}")

            except Exception as e:
                print(f"[{i}/{total}] FAILED: {f.name}")
                traceback.print_exc()

        print(f"✅ Done. Loaded {loaded}, skipped {skipped}, total {total}.")

        # Quick count (optional)
        try:
            with conn.cursor() as cur:
                cur.execute(f"SELECT COUNT(*) FROM `{TABLE}`;")
                cnt = cur.fetchone()[0]
            print(f"Rows now in `{TABLE}`: {cnt}")
        except Exception:
            pass

    finally:
        conn.close()


# Run immediately (works in notebooks too)
main()

# %%
pip install xlsx2csv

# %%
"""
import_xlsx_to_mysql.py
=======================

This script demonstrates how to ingest many large Excel (.xlsx) files into
a single MySQL table.  It is designed to handle files with hundreds of
thousands of rows by streaming data in chunks rather than loading the
entire file into memory at once.

The script uses `pandas.read_excel()` with the `chunksize` parameter to
iterate over each workbook in manageable blocks.  Reading in chunks
dramatically reduces memory usage and is recommended when working with
large spreadsheets【56988329124830†L34-L71】.  Each chunk is appended
directly to a MySQL table using SQLAlchemy's `to_sql()` convenience
function.  The `method='multi'` argument instructs pandas to bulk
insert rows in groups which improves performance.

Before running this script you need to:

* Install the required Python packages.  At a minimum you will need
  `pandas`, `sqlalchemy` and a MySQL driver like `pymysql`.  You can
  install these packages with pip:

      pip install pandas sqlalchemy pymysql

* Create a MySQL database and ensure you have credentials with write
  access.  Update the placeholders for `MYSQL_USER`, `MYSQL_PASSWORD`,
  `MYSQL_HOST`, `MYSQL_PORT` and `MYSQL_DB` in the configuration
  section below.

* Place all your `.xlsx` files in a single directory.  In the example
  below this directory is called `mysql_Database/0_Done` relative to
  the current working directory, but you can change `DATA_DIR` to
  point anywhere on your filesystem.

When executed, the script will loop over every `.xlsx` file found in
`DATA_DIR`.  For each file it opens the workbook with pandas and
iterates through the rows in chunks of size `CHUNK_SIZE`.  Each
chunk is then appended to a table named `comp` in your MySQL
database.  If the table does not already exist, pandas will create it
automatically using the column names discovered in the first chunk.
"""

import os
import sys
from typing import Optional

import pandas as pd  # type: ignore
from sqlalchemy import create_engine  # type: ignore


# ---------------------------------------------------------------------------
# Configuration
# Update these values with your actual MySQL connection details and data
# location.  For security, you may prefer to read credentials from
# environment variables instead of hard‑coding them here.
# ---------------------------------------------------------------------------

# Directory containing all of your `.xlsx` files.  If the user has
# placed the folder on the desktop as described (e.g. `~/Desktop/mysql_Database/0_Done`),
# update this path accordingly.  Use an absolute path to avoid
# confusion when the script is run from another working directory.
DATA_DIR: str = os.path.expanduser(".")

# MySQL connection parameters
MYSQL_USER: str = 'root'
MYSQL_PASSWORD: str = ""
MYSQL_HOST: str = "localhost"
MYSQL_PORT: int = 3306
MYSQL_DB: str = "saurabh"

# Name of the destination table in MySQL.  All data from every Excel
# file will be appended to this table.
TABLE_NAME: str = "comp"

# Number of rows per chunk when reading Excel files.  Adjust this
# value based on available memory and performance characteristics.  A
# smaller `chunksize` reduces memory usage at the cost of more
# insert operations.  The Finxter article suggests 10,000 rows as a
# reasonable starting point【56988329124830†L51-L71】.
CHUNK_SIZE: int = 10000


def get_engine() -> "sqlalchemy.engine.Engine":
    """Create a SQLAlchemy engine for MySQL using the configured credentials.

    Returns
    -------
    sqlalchemy.engine.Engine
        A SQLAlchemy engine connected to the configured MySQL database.
    """
    # Using the `pymysql` driver provides a pure‑Python MySQL client
    # compatible with SQLAlchemy.  The connection string is in the form
    # "mysql+pymysql://user:password@host:port/database".
    url = (
        f"mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}:"
        f"{MYSQL_PORT}/{MYSQL_DB}"
    )
    return create_engine(url, pool_recycle=3600)


def process_file(file_path: str, engine) -> None:
    """Read an Excel file in chunks and append its data to the MySQL table.

    Parameters
    ----------
    file_path : str
        Path to the `.xlsx` file to be processed.
    engine : sqlalchemy.engine.Engine
        SQLAlchemy engine used to connect to the MySQL database.
    """
    # Use pandas to read the Excel file in chunks.  The `chunksize`
    # parameter enables streaming through the file【56988329124830†L34-L71】.
    try:
        for idx, chunk in enumerate(
            pd.read_excel(file_path, chunksize=CHUNK_SIZE, engine="openpyxl")
        ):
            # Normalize column names: strip whitespace and replace spaces with
            # underscores.  This helps avoid issues with MySQL column names.
            chunk.columns = [
                str(col).strip().replace(" ", "_") for col in chunk.columns
            ]
            # Append the chunk to the target table.  The `if_exists='append'`
            # argument ensures that subsequent chunks are appended rather
            # than replacing the table.  Setting `index=False` prevents
            # pandas from writing the DataFrame index as a column.  The
            # `method='multi'` argument groups many rows into a single
            # `INSERT` statement which improves performance.
            chunk.to_sql(
                TABLE_NAME,
                con=engine,
                if_exists="append",
                index=False,
                method="multi",
            )
            print(f"Inserted chunk {idx + 1} from {os.path.basename(file_path)}")
    except Exception as exc:
        print(f"Error processing {file_path}: {exc}")


def main(data_dir: Optional[str] = None) -> None:
    """Iterate over all Excel files in the directory and load them into MySQL.

    Parameters
    ----------
    data_dir : str, optional
        Directory containing `.xlsx` files to be processed.  If omitted
        the global `DATA_DIR` value will be used.
    """
    dir_path = data_dir or DATA_DIR
    if not os.path.isdir(dir_path):
        print(
            f"Data directory '{dir_path}' does not exist.  Please update the"
            " DATA_DIR variable or provide a valid path."
        )
        sys.exit(1)

    # Create the SQLAlchemy engine outside the file loop to reuse
    # connections between files.
    engine = get_engine()

    # Find all `.xlsx` files in the directory.  Sorting the list makes
    # the processing order deterministic which can aid debugging.
    excel_files = [
        os.path.join(dir_path, f)
        for f in sorted(os.listdir(dir_path))
        if f.lower().endswith(".xlsx")
    ]

    if not excel_files:
        print(
            f"No .xlsx files found in '{dir_path}'.  Please ensure the"
            " directory contains the Excel files you wish to import."
        )
        sys.exit(1)

    # Process each file one after the other.
    for file_path in excel_files:
        print(f"\nProcessing file: {os.path.basename(file_path)}")
        process_file(file_path, engine)
        print(f"Finished processing {os.path.basename(file_path)}")

    print("\nAll files have been processed and loaded into the MySQL table.")


if __name__ == "__main__":
    main()

# %%
"""
import_xlsx_to_mysql.py
=======================

This script demonstrates how to ingest many large Excel (.xlsx) files into
a single MySQL table.  It is designed to handle files with hundreds of
thousands of rows by streaming data in chunks rather than loading the
entire file into memory at once.

The script uses `pandas.read_excel()` with the `chunksize` parameter to
iterate over each workbook in manageable blocks.  Reading in chunks
dramatically reduces memory usage and is recommended when working with
large spreadsheets【56988329124830†L34-L71】.  Each chunk is appended
directly to a MySQL table using SQLAlchemy's `to_sql()` convenience
function.  The `method='multi'` argument instructs pandas to bulk
insert rows in groups which improves performance.

Before running this script you need to:

* Install the required Python packages.  At a minimum you will need
  `pandas`, `sqlalchemy` and a MySQL driver like `pymysql`.  You can
  install these packages with pip:

      pip install pandas sqlalchemy pymysql

* Create a MySQL database and ensure you have credentials with write
  access.  Update the placeholders for `MYSQL_USER`, `MYSQL_PASSWORD`,
  `MYSQL_HOST`, `MYSQL_PORT` and `MYSQL_DB` in the configuration
  section below.

* Place all your `.xlsx` files in a single directory.  In the example
  below this directory is called `mysql_Database/0_Done` relative to
  the current working directory, but you can change `DATA_DIR` to
  point anywhere on your filesystem.

When executed, the script will loop over every `.xlsx` file found in
`DATA_DIR`.  For each file it opens the workbook with pandas and
iterates through the rows in chunks of size `CHUNK_SIZE`.  Each
chunk is then appended to a table named `comp` in your MySQL
database.  If the table does not already exist, pandas will create it
automatically using the column names discovered in the first chunk.
"""

import os
import sys
from typing import Optional

import pandas as pd  # type: ignore
from sqlalchemy import create_engine  # type: ignore


# ---------------------------------------------------------------------------
# Configuration
# Update these values with your actual MySQL connection details and data
# location.  For security, you may prefer to read credentials from
# environment variables instead of hard‑coding them here.
# ---------------------------------------------------------------------------

# Directory containing all of your `.xlsx` files.  If the user has
# placed the folder on the desktop as described (e.g. `~/Desktop/mysql_Database/0_Done`),
# update this path accordingly.  Use an absolute path to avoid
# confusion when the script is run from another working directory.
DATA_DIR: str = os.path.expanduser(".")

# MySQL connection parameters
MYSQL_USER: str = 'root'
MYSQL_PASSWORD: str = ""
MYSQL_HOST: str = "localhost"
MYSQL_PORT: int = 3306
MYSQL_DB: str = "saurabh"

# Name of the destination table in MySQL.  All data from every Excel
# file will be appended to this table.
TABLE_NAME: str = "comp"

# Number of rows per chunk when reading Excel files.  Adjust this
# value based on available memory and performance characteristics.  A
# smaller `chunksize` reduces memory usage at the cost of more
# insert operations.  The Finxter article suggests 10,000 rows as a
# reasonable starting point【56988329124830†L51-L71】.
CHUNK_SIZE: int = 10000


def get_engine() -> "sqlalchemy.engine.Engine":
    """Create a SQLAlchemy engine for MySQL using the configured credentials.

    Returns
    -------
    sqlalchemy.engine.Engine
        A SQLAlchemy engine connected to the configured MySQL database.
    """
    # Using the `pymysql` driver provides a pure‑Python MySQL client
    # compatible with SQLAlchemy.  The connection string is in the form
    # "mysql+pymysql://user:password@host:port/database".
    url = (
        f"mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}:"
        f"{MYSQL_PORT}/{MYSQL_DB}"
    )
    return create_engine(url, pool_recycle=3600)


def process_file(file_path: str, engine) -> None:
    """Read an Excel file in chunks and append its data to the MySQL table.

    This function supports both modern pandas versions that accept a
    `chunksize` argument on `read_excel()` and older versions where
    that parameter is unavailable.  When `chunksize` is not supported,
    the function falls back to manually reading the file in slices
    using the `nrows` and `skiprows` parameters【21391296221340†L1240-L1265】.

    Parameters
    ----------
    file_path : str
        Path to the `.xlsx` file to be processed.
    engine : sqlalchemy.engine.Engine
        SQLAlchemy engine used to connect to the MySQL database.
    """
    import inspect

    # Determine whether the pandas.read_excel signature includes
    # `chunksize`.  If so, use native chunk iteration; otherwise fall
    # back to manual chunking.
    read_excel_sig = inspect.signature(pd.read_excel)
    supports_chunksize = "chunksize" in read_excel_sig.parameters

    try:
        if supports_chunksize:
            # Use native chunked reading available in newer versions of pandas.
            for idx, chunk in enumerate(
                pd.read_excel(file_path, chunksize=CHUNK_SIZE, engine="openpyxl")
            ):
                # Normalize column names: strip whitespace and replace spaces with
                # underscores.  This helps avoid issues with MySQL column names.
                chunk.columns = [
                    str(col).strip().replace(" ", "_") for col in chunk.columns
                ]
                chunk.to_sql(
                    TABLE_NAME,
                    con=engine,
                    if_exists="append",
                    index=False,
                    method="multi",
                )
                print(
                    f"Inserted chunk {idx + 1} from {os.path.basename(file_path)}"
                )
        else:
            # Manual chunking for pandas versions without `chunksize` support【21391296221340†L1240-L1265】.
            # First read the header to obtain column names.
            header_df = pd.read_excel(
                file_path,
                nrows=0,
                engine="openpyxl",
            )
            column_names = [
                str(col).strip().replace(" ", "_") for col in header_df.columns
            ]
            offset = 0
            chunk_idx = 0
            while True:
                # Skip the header row and previously read rows.
                skiprows = range(1, offset + 1)
                chunk = pd.read_excel(
                    file_path,
                    nrows=CHUNK_SIZE,
                    skiprows=skiprows,
                    header=None,
                    names=column_names,
                    engine="openpyxl",
                )
                # Stop when no more rows are returned.
                if chunk.empty:
                    break
                # Append the chunk to the database.
                chunk.to_sql(
                    TABLE_NAME,
                    con=engine,
                    if_exists="append",
                    index=False,
                    method="multi",
                )
                chunk_idx += 1
                print(
                    f"Inserted chunk {chunk_idx} from {os.path.basename(file_path)}"
                )
                offset += CHUNK_SIZE
    except Exception as exc:
        print(f"Error processing {file_path}: {exc}")


def main(data_dir: Optional[str] = None) -> None:
    """Iterate over all Excel files in the directory and load them into MySQL.

    Parameters
    ----------
    data_dir : str, optional
        Directory containing `.xlsx` files to be processed.  If omitted
        the global `DATA_DIR` value will be used.
    """
    dir_path = data_dir or DATA_DIR
    if not os.path.isdir(dir_path):
        print(
            f"Data directory '{dir_path}' does not exist.  Please update the"
            " DATA_DIR variable or provide a valid path."
        )
        sys.exit(1)

    # Create the SQLAlchemy engine outside the file loop to reuse
    # connections between files.
    engine = get_engine()

    # Find all `.xlsx` files in the directory.  Sorting the list makes
    # the processing order deterministic which can aid debugging.
    excel_files = [
        os.path.join(dir_path, f)
        for f in sorted(os.listdir(dir_path))
        if f.lower().endswith(".xlsx")
    ]

    if not excel_files:
        print(
            f"No .xlsx files found in '{dir_path}'.  Please ensure the"
            " directory contains the Excel files you wish to import."
        )
        sys.exit(1)

    # Process each file one after the other.
    for file_path in excel_files:
        print(f"\nProcessing file: {os.path.basename(file_path)}")
        process_file(file_path, engine)
        print(f"Finished processing {os.path.basename(file_path)}")

    print("\nAll files have been processed and loaded into the MySQL table.")


if __name__ == "__main__":
    main()
# Out:
# Processing file: ABB.xlsx
# Inserted chunk 1 from ABB.xlsx
# Inserted chunk 2 from ABB.xlsx
# Inserted chunk 3 from ABB.xlsx
# Inserted chunk 4 from ABB.xlsx
# Inserted chunk 5 from ABB.xlsx
# Inserted chunk 6 from ABB.xlsx
# Inserted chunk 7 from ABB.xlsx
# Inserted chunk 8 from ABB.xlsx
# Inserted chunk 9 from ABB.xlsx
# Inserted chunk 10 from ABB.xlsx
# Inserted chunk 11 from ABB.xlsx
# Inserted chunk 12 from ABB.xlsx
# Inserted chunk 13 from ABB.xlsx
# Inserted chunk 14 from ABB.xlsx
# Inserted chunk 15 from ABB.xlsx
# Inserted chunk 16 from ABB.xlsx
# Inserted chunk 17 from ABB.xlsx
# Inserted chunk 18 from ABB.xlsx
# Inserted chunk 19 from ABB.xlsx
# Inserted chunk 20 from ABB.xlsx
# Inserted chunk 21 from ABB.xlsx
# Inserted chunk 22 from ABB.xlsx
# Inserted chunk 23 from ABB.xlsx
# Inserted chunk 24 from ABB.xlsx
# Inserted chunk 25 from ABB.xlsx
# Inserted chunk 26 from ABB.xlsx
# Inserted chunk 27 from ABB.xlsx
# Inserted chunk 28 from ABB.xlsx
# Inserted chunk 29 from ABB.xlsx
# Inserted chunk 30 from ABB.xlsx
# Inserted chunk 31 from ABB.xlsx
# Inserted chunk 32 from ABB.xlsx
# Inserted chunk 33 from ABB.xlsx
# Inserted chunk 34 from ABB.xlsx
# Inserted chunk 35 from ABB.xlsx
# Inserted chunk 36 from ABB.xlsx
# Inserted chunk 37 from ABB.xlsx
# Inserted chunk 38 from ABB.xlsx
# Inserted chunk 39 from ABB.xlsx
# Inserted chunk 40 from ABB.xlsx
# Inserted chunk 41 from ABB.xlsx
# Inserted chunk 42 from ABB.xlsx
# Inserted chunk 43 from ABB.xlsx
# Inserted chunk 44 from ABB.xlsx
# Inserted chunk 45 from ABB.xlsx
# Inserted chunk 46 from ABB.xlsx
# Inserted chunk 47 from ABB.xlsx
# Inserted chunk 48 from ABB.xlsx
# Inserted chunk 49 from ABB.xlsx
# Inserted chunk 50 from ABB.xlsx
# Inserted chunk 51 from ABB.xlsx
# Inserted chunk 52 from ABB.xlsx
# Inserted chunk 53 from ABB.xlsx
# Inserted chunk 54 from ABB.xlsx
# Inserted chunk 55 from ABB.xlsx
# Inserted chunk 56 from ABB.xlsx
# Inserted chunk 57 from ABB.xlsx
# Inserted chunk 58 from ABB.xlsx
# Inserted chunk 59 from ABB.xlsx
# Inserted chunk 60 from ABB.xlsx
# Inserted chunk 61 from ABB.xlsx
# Inserted chunk 62 from ABB.xlsx
# Inserted chunk 63 from ABB.xlsx
# Inserted chunk 64 from ABB.xlsx
# Inserted chunk 65 from ABB.xlsx
# Inserted chunk 66 from ABB.xlsx
# Inserted chunk 67 from ABB.xlsx
# Inserted chunk 68 from ABB.xlsx
# Inserted chunk 69 from ABB.xlsx
# Inserted chunk 70 from ABB.xlsx
# Inserted chunk 71 from ABB.xlsx
# Inserted chunk 72 from ABB.xlsx
# Inserted chunk 73 from ABB.xlsx
# Inserted chunk 74 from ABB.xlsx
# Inserted chunk 75 from ABB.xlsx
# Inserted chunk 76 from ABB.xlsx
# Inserted chunk 77 from ABB.xlsx
# Inserted chunk 78 from ABB.xlsx
# Inserted chunk 79 from ABB.xlsx
# Inserted chunk 80 from ABB.xlsx
# Inserted chunk 81 from ABB.xlsx
# Inserted chunk 82 from ABB.xlsx
# Inserted chunk 83 from ABB.xlsx
# Inserted chunk 84 from ABB.xlsx
# Inserted chunk 85 from ABB.xlsx
# Inserted chunk 86 from ABB.xlsx
# Inserted chunk 87 from ABB.xlsx
# Inserted chunk 88 from ABB.xlsx
# Inserted chunk 89 from ABB.xlsx
# Inserted chunk 90 from ABB.xlsx
# Inserted chunk 91 from ABB.xlsx
# Inserted chunk 92 from ABB.xlsx
# Inserted chunk 93 from ABB.xlsx
# Inserted chunk 94 from ABB.xlsx
# Inserted chunk 95 from ABB.xlsx
# Inserted chunk 96 from ABB.xlsx
# Inserted chunk 97 from ABB.xlsx
# Inserted chunk 98 from ABB.xlsx
# Inserted chunk 99 from ABB.xlsx
# Inserted chunk 100 from ABB.xlsx
# Inserted chunk 101 from ABB.xlsx
# Inserted chunk 102 from ABB.xlsx
# Inserted chunk 103 from ABB.xlsx
# Inserted chunk 104 from ABB.xlsx
# Inserted chunk 105 from ABB.xlsx
# Inserted chunk 106 from ABB.xlsx
# Inserted chunk 107 from ABB.xlsx
# Inserted chunk 108 from ABB.xlsx
# Inserted chunk 109 from ABB.xlsx
# Inserted chunk 110 from ABB.xlsx
# Inserted chunk 111 from ABB.xlsx
# Inserted chunk 112 from ABB.xlsx
# Inserted chunk 113 from ABB.xlsx
# Inserted chunk 114 from ABB.xlsx
# Inserted chunk 115 from ABB.xlsx
# Inserted chunk 116 from ABB.xlsx
# Inserted chunk 117 from ABB.xlsx
# Inserted chunk 118 from ABB.xlsx
# Inserted chunk 119 from ABB.xlsx
# Inserted chunk 120 from ABB.xlsx
# Inserted chunk 121 from ABB.xlsx
# Inserted chunk 122 from ABB.xlsx
# Inserted chunk 123 from ABB.xlsx
# Inserted chunk 124 from ABB.xlsx
# Inserted chunk 125 from ABB.xlsx
# Inserted chunk 126 from ABB.xlsx
# Inserted chunk 127 from ABB.xlsx
# Inserted chunk 128 from ABB.xlsx
# Inserted chunk 129 from ABB.xlsx
# Inserted chunk 130 from ABB.xlsx
# Inserted chunk 131 from ABB.xlsx
# Inserted chunk 132 from ABB.xlsx
# Inserted chunk 133 from ABB.xlsx
# Inserted chunk 134 from ABB.xlsx
# Inserted chunk 135 from ABB.xlsx
# Inserted chunk 136 from ABB.xlsx
# Inserted chunk 137 from ABB.xlsx
# Inserted chunk 138 from ABB.xlsx
# Inserted chunk 139 from ABB.xlsx
# Inserted chunk 140 from ABB.xlsx
# Inserted chunk 141 from ABB.xlsx
# Inserted chunk 142 from ABB.xlsx
# Inserted chunk 143 from ABB.xlsx
# Inserted chunk 144 from ABB.xlsx
# Inserted chunk 145 from ABB.xlsx
# Inserted chunk 146 from ABB.xlsx
# Inserted chunk 147 from ABB.xlsx
# Inserted chunk 148 from ABB.xlsx
# Inserted chunk 149 from ABB.xlsx
# Inserted chunk 150 from ABB.xlsx
# Inserted chunk 151 from ABB.xlsx
# Inserted chunk 152 from ABB.xlsx
# Inserted chunk 153 from ABB.xlsx
# Inserted chunk 154 from ABB.xlsx
# Inserted chunk 155 from ABB.xlsx
# Inserted chunk 156 from ABB.xlsx
# Inserted chunk 157 from ABB.xlsx
# Inserted chunk 158 from ABB.xlsx
# Inserted chunk 159 from ABB.xlsx
# Inserted chunk 160 from ABB.xlsx
# Inserted chunk 161 from ABB.xlsx
# Inserted chunk 162 from ABB.xlsx
# Inserted chunk 163 from ABB.xlsx
# Inserted chunk 164 from ABB.xlsx
# Inserted chunk 165 from ABB.xlsx
# Inserted chunk 166 from ABB.xlsx
# Inserted chunk 167 from ABB.xlsx
# Inserted chunk 168 from ABB.xlsx
# Inserted chunk 169 from ABB.xlsx
# Inserted chunk 170 from ABB.xlsx
# Inserted chunk 171 from ABB.xlsx
# Inserted chunk 172 from ABB.xlsx
# Inserted chunk 173 from ABB.xlsx
# Inserted chunk 174 from ABB.xlsx
# Inserted chunk 175 from ABB.xlsx
# Inserted chunk 176 from ABB.xlsx
# Inserted chunk 177 from ABB.xlsx
# Inserted chunk 178 from ABB.xlsx
# Inserted chunk 179 from ABB.xlsx
# Inserted chunk 180 from ABB.xlsx
# Inserted chunk 181 from ABB.xlsx
# Inserted chunk 182 from ABB.xlsx
# Inserted chunk 183 from ABB.xlsx
# Inserted chunk 184 from ABB.xlsx
# Inserted chunk 185 from ABB.xlsx
# Inserted chunk 186 from ABB.xlsx
# Inserted chunk 187 from ABB.xlsx
# Inserted chunk 188 from ABB.xlsx
# Inserted chunk 189 from ABB.xlsx
# Inserted chunk 190 from ABB.xlsx
# Inserted chunk 191 from ABB.xlsx
# Inserted chunk 192 from ABB.xlsx
# Inserted chunk 193 from ABB.xlsx
# Inserted chunk 194 from ABB.xlsx
# Inserted chunk 195 from ABB.xlsx
# Inserted chunk 196 from ABB.xlsx
# Inserted chunk 197 from ABB.xlsx
# Inserted chunk 198 from ABB.xlsx
# Inserted chunk 199 from ABB.xlsx
# Inserted chunk 200 from ABB.xlsx
# Inserted chunk 201 from ABB.xlsx
# Inserted chunk 202 from ABB.xlsx
# Inserted chunk 203 from ABB.xlsx
# Inserted chunk 204 from ABB.xlsx
# Inserted chunk 205 from ABB.xlsx
# Inserted chunk 206 from ABB.xlsx
# Inserted chunk 207 from ABB.xlsx
# Inserted chunk 208 from ABB.xlsx
# Inserted chunk 209 from ABB.xlsx
# Inserted chunk 210 from ABB.xlsx
# Inserted chunk 211 from ABB.xlsx
# Inserted chunk 212 from ABB.xlsx
# Inserted chunk 213 from ABB.xlsx
# Inserted chunk 214 from ABB.xlsx
# Inserted chunk 215 from ABB.xlsx
# Inserted chunk 216 from ABB.xlsx
# Inserted chunk 217 from ABB.xlsx
# Inserted chunk 218 from ABB.xlsx
# Inserted chunk 219 from ABB.xlsx
# Inserted chunk 220 from ABB.xlsx
# Inserted chunk 221 from ABB.xlsx
# Inserted chunk 222 from ABB.xlsx
# Inserted chunk 223 from ABB.xlsx
# Inserted chunk 224 from ABB.xlsx
# Inserted chunk 225 from ABB.xlsx
# Inserted chunk 226 from ABB.xlsx
# Inserted chunk 227 from ABB.xlsx
# Inserted chunk 228 from ABB.xlsx
# Inserted chunk 229 from ABB.xlsx
# Inserted chunk 230 from ABB.xlsx
# Inserted chunk 231 from ABB.xlsx
# Inserted chunk 232 from ABB.xlsx
# Inserted chunk 233 from ABB.xlsx
# Inserted chunk 234 from ABB.xlsx
# Inserted chunk 235 from ABB.xlsx
# Inserted chunk 236 from ABB.xlsx
# Inserted chunk 237 from ABB.xlsx
# Inserted chunk 238 from ABB.xlsx
# Inserted chunk 239 from ABB.xlsx
# Inserted chunk 240 from ABB.xlsx
# Inserted chunk 241 from ABB.xlsx
# Inserted chunk 242 from ABB.xlsx
# Inserted chunk 243 from ABB.xlsx
# Inserted chunk 244 from ABB.xlsx
# Inserted chunk 245 from ABB.xlsx
# Inserted chunk 246 from ABB.xlsx
# Inserted chunk 247 from ABB.xlsx
# Inserted chunk 248 from ABB.xlsx
# Inserted chunk 249 from ABB.xlsx
# Inserted chunk 250 from ABB.xlsx
# Inserted chunk 251 from ABB.xlsx
# Inserted chunk 252 from ABB.xlsx
# Inserted chunk 253 from ABB.xlsx
# Inserted chunk 254 from ABB.xlsx
# Inserted chunk 255 from ABB.xlsx
# Inserted chunk 256 from ABB.xlsx
# Inserted chunk 257 from ABB.xlsx
# Inserted chunk 258 from ABB.xlsx
# Inserted chunk 259 from ABB.xlsx
# Inserted chunk 260 from ABB.xlsx
# Inserted chunk 261 from ABB.xlsx
# Inserted chunk 262 from ABB.xlsx
# Inserted chunk 263 from ABB.xlsx
# Inserted chunk 264 from ABB.xlsx
# Inserted chunk 265 from ABB.xlsx
# Inserted chunk 266 from ABB.xlsx
# Inserted chunk 267 from ABB.xlsx
# Inserted chunk 268 from ABB.xlsx
# Inserted chunk 269 from ABB.xlsx
# Inserted chunk 270 from ABB.xlsx
# Inserted chunk 271 from ABB.xlsx
# Inserted chunk 272 from ABB.xlsx
# Inserted chunk 273 from ABB.xlsx
# Inserted chunk 274 from ABB.xlsx
# Inserted chunk 275 from ABB.xlsx
# Inserted chunk 276 from ABB.xlsx
# Inserted chunk 277 from ABB.xlsx
# Inserted chunk 278 from ABB.xlsx
# Inserted chunk 279 from ABB.xlsx
# Inserted chunk 280 from ABB.xlsx
# Inserted chunk 281 from ABB.xlsx
# Inserted chunk 282 from ABB.xlsx
# Inserted chunk 283 from ABB.xlsx
# Inserted chunk 284 from ABB.xlsx
# Inserted chunk 285 from ABB.xlsx
# Inserted chunk 286 from ABB.xlsx
# Inserted chunk 287 from ABB.xlsx
# Inserted chunk 288 from ABB.xlsx
# Inserted chunk 289 from ABB.xlsx
# Inserted chunk 290 from ABB.xlsx
# Inserted chunk 291 from ABB.xlsx
# Inserted chunk 292 from ABB.xlsx
# Inserted chunk 293 from ABB.xlsx
# Inserted chunk 294 from ABB.xlsx
# Inserted chunk 295 from ABB.xlsx
# Inserted chunk 296 from ABB.xlsx
# Inserted chunk 297 from ABB.xlsx
# Inserted chunk 298 from ABB.xlsx
# Inserted chunk 299 from ABB.xlsx
# Inserted chunk 300 from ABB.xlsx
# Inserted chunk 301 from ABB.xlsx
# Inserted chunk 302 from ABB.xlsx
# Inserted chunk 303 from ABB.xlsx
# Inserted chunk 304 from ABB.xlsx
# Inserted chunk 305 from ABB.xlsx
# Inserted chunk 306 from ABB.xlsx
# Inserted chunk 307 from ABB.xlsx
# Inserted chunk 308 from ABB.xlsx
# Inserted chunk 309 from ABB.xlsx
# Inserted chunk 310 from ABB.xlsx
# Inserted chunk 311 from ABB.xlsx
# Inserted chunk 312 from ABB.xlsx
# Inserted chunk 313 from ABB.xlsx
# Inserted chunk 314 from ABB.xlsx
# Inserted chunk 315 from ABB.xlsx
# Inserted chunk 316 from ABB.xlsx
# Inserted chunk 317 from ABB.xlsx
# Inserted chunk 318 from ABB.xlsx
# Inserted chunk 319 from ABB.xlsx
# Inserted chunk 320 from ABB.xlsx
# Inserted chunk 321 from ABB.xlsx
# Inserted chunk 322 from ABB.xlsx
# Inserted chunk 323 from ABB.xlsx
# Inserted chunk 324 from ABB.xlsx
# Inserted chunk 325 from ABB.xlsx
# Inserted chunk 326 from ABB.xlsx
# Inserted chunk 327 from ABB.xlsx
# Inserted chunk 328 from ABB.xlsx
# Inserted chunk 329 from ABB.xlsx
# Inserted chunk 330 from ABB.xlsx
# Inserted chunk 331 from ABB.xlsx
# Inserted chunk 332 from ABB.xlsx
# Inserted chunk 333 from ABB.xlsx
# Inserted chunk 334 from ABB.xlsx
# Inserted chunk 335 from ABB.xlsx
# Inserted chunk 336 from ABB.xlsx
# Inserted chunk 337 from ABB.xlsx
# Inserted chunk 338 from ABB.xlsx
# Inserted chunk 339 from ABB.xlsx
# Inserted chunk 340 from ABB.xlsx
# Inserted chunk 341 from ABB.xlsx
# Inserted chunk 342 from ABB.xlsx
# Inserted chunk 343 from ABB.xlsx
# Inserted chunk 344 from ABB.xlsx
# Inserted chunk 345 from ABB.xlsx
# Inserted chunk 346 from ABB.xlsx
# Inserted chunk 347 from ABB.xlsx
# Inserted chunk 348 from ABB.xlsx
# Inserted chunk 349 from ABB.xlsx
# Inserted chunk 350 from ABB.xlsx
# Inserted chunk 351 from ABB.xlsx
# Inserted chunk 352 from ABB.xlsx
# Inserted chunk 353 from ABB.xlsx
# Inserted chunk 354 from ABB.xlsx
# Inserted chunk 355 from ABB.xlsx
# Inserted chunk 356 from ABB.xlsx
# Inserted chunk 357 from ABB.xlsx
# Inserted chunk 358 from ABB.xlsx
# Inserted chunk 359 from ABB.xlsx
# Inserted chunk 360 from ABB.xlsx
# Inserted chunk 361 from ABB.xlsx
# Inserted chunk 362 from ABB.xlsx
# Inserted chunk 363 from ABB.xlsx
# Inserted chunk 364 from ABB.xlsx
# Inserted chunk 365 from ABB.xlsx
# Inserted chunk 366 from ABB.xlsx
# Inserted chunk 367 from ABB.xlsx
# Inserted chunk 368 from ABB.xlsx
# Inserted chunk 369 from ABB.xlsx
# Inserted chunk 370 from ABB.xlsx
# Inserted chunk 371 from ABB.xlsx
# Inserted chunk 372 from ABB.xlsx
# Inserted chunk 373 from ABB.xlsx
# Inserted chunk 374 from ABB.xlsx
# Inserted chunk 375 from ABB.xlsx
# Inserted chunk 376 from ABB.xlsx
# Inserted chunk 377 from ABB.xlsx
# Inserted chunk 378 from ABB.xlsx
# Inserted chunk 379 from ABB.xlsx
# Inserted chunk 380 from ABB.xlsx
# Inserted chunk 381 from ABB.xlsx
# Inserted chunk 382 from ABB.xlsx
# Inserted chunk 383 from ABB.xlsx
# Inserted chunk 384 from ABB.xlsx
# Inserted chunk 385 from ABB.xlsx
# Inserted chunk 386 from ABB.xlsx
# Inserted chunk 387 from ABB.xlsx
# Inserted chunk 388 from ABB.xlsx
# Inserted chunk 389 from ABB.xlsx
# Inserted chunk 390 from ABB.xlsx
# Inserted chunk 391 from ABB.xlsx
# Inserted chunk 392 from ABB.xlsx
# Inserted chunk 393 from ABB.xlsx
# Inserted chunk 394 from ABB.xlsx
# Inserted chunk 395 from ABB.xlsx
# Inserted chunk 396 from ABB.xlsx
# Inserted chunk 397 from ABB.xlsx
# Inserted chunk 398 from ABB.xlsx
# Inserted chunk 399 from ABB.xlsx
# Inserted chunk 400 from ABB.xlsx
# Inserted chunk 401 from ABB.xlsx
# Inserted chunk 402 from ABB.xlsx
# Inserted chunk 403 from ABB.xlsx
# Inserted chunk 404 from ABB.xlsx
# Inserted chunk 405 from ABB.xlsx
# Inserted chunk 406 from ABB.xlsx
# Inserted chunk 407 from ABB.xlsx
# Inserted chunk 408 from ABB.xlsx
# Inserted chunk 409 from ABB.xlsx
# Inserted chunk 410 from ABB.xlsx
# Inserted chunk 411 from ABB.xlsx
# Inserted chunk 412 from ABB.xlsx
# Inserted chunk 413 from ABB.xlsx
# Inserted chunk 414 from ABB.xlsx
# Inserted chunk 415 from ABB.xlsx
# Inserted chunk 416 from ABB.xlsx
# Inserted chunk 417 from ABB.xlsx
# Inserted chunk 418 from ABB.xlsx
# Inserted chunk 419 from ABB.xlsx
# Inserted chunk 420 from ABB.xlsx
# Inserted chunk 421 from ABB.xlsx
# Inserted chunk 422 from ABB.xlsx
# Inserted chunk 423 from ABB.xlsx
# Inserted chunk 424 from ABB.xlsx
# Inserted chunk 425 from ABB.xlsx
# Inserted chunk 426 from ABB.xlsx
# Inserted chunk 427 from ABB.xlsx
# Inserted chunk 428 from ABB.xlsx
# Inserted chunk 429 from ABB.xlsx
# Inserted chunk 430 from ABB.xlsx
# Inserted chunk 431 from ABB.xlsx
# Inserted chunk 432 from ABB.xlsx
# Inserted chunk 433 from ABB.xlsx
# Inserted chunk 434 from ABB.xlsx
# Inserted chunk 435 from ABB.xlsx
# Inserted chunk 436 from ABB.xlsx
# Inserted chunk 437 from ABB.xlsx
# Inserted chunk 438 from ABB.xlsx
# Inserted chunk 439 from ABB.xlsx
# Inserted chunk 440 from ABB.xlsx
# Inserted chunk 441 from ABB.xlsx
# Inserted chunk 442 from ABB.xlsx
# Inserted chunk 443 from ABB.xlsx
# Inserted chunk 444 from ABB.xlsx
# Inserted chunk 445 from ABB.xlsx
# Inserted chunk 446 from ABB.xlsx
# Inserted chunk 447 from ABB.xlsx
# Inserted chunk 448 from ABB.xlsx
# Inserted chunk 449 from ABB.xlsx
# Inserted chunk 450 from ABB.xlsx
# Inserted chunk 451 from ABB.xlsx
# Inserted chunk 452 from ABB.xlsx
# Inserted chunk 453 from ABB.xlsx
# Inserted chunk 454 from ABB.xlsx
# Inserted chunk 455 from ABB.xlsx
# Inserted chunk 456 from ABB.xlsx
# Inserted chunk 457 from ABB.xlsx
# Inserted chunk 458 from ABB.xlsx
# Inserted chunk 459 from ABB.xlsx
# Inserted chunk 460 from ABB.xlsx
# Inserted chunk 461 from ABB.xlsx
# Inserted chunk 462 from ABB.xlsx
# Inserted chunk 463 from ABB.xlsx
# Inserted chunk 464 from ABB.xlsx
# Inserted chunk 465 from ABB.xlsx
# Inserted chunk 466 from ABB.xlsx
# Inserted chunk 467 from ABB.xlsx
# Inserted chunk 468 from ABB.xlsx
# Inserted chunk 469 from ABB.xlsx
# Inserted chunk 470 from ABB.xlsx
# Inserted chunk 471 from ABB.xlsx
# Inserted chunk 472 from ABB.xlsx
# Inserted chunk 473 from ABB.xlsx
# Inserted chunk 474 from ABB.xlsx
# Inserted chunk 475 from ABB.xlsx
# Inserted chunk 476 from ABB.xlsx
# Inserted chunk 477 from ABB.xlsx
# Inserted chunk 478 from ABB.xlsx
# Inserted chunk 479 from ABB.xlsx
# Inserted chunk 480 from ABB.xlsx
# Inserted chunk 481 from ABB.xlsx
# Inserted chunk 482 from ABB.xlsx
# Inserted chunk 483 from ABB.xlsx
# Inserted chunk 484 from ABB.xlsx
# Inserted chunk 485 from ABB.xlsx
# Inserted chunk 486 from ABB.xlsx
# Inserted chunk 487 from ABB.xlsx
# Inserted chunk 488 from ABB.xlsx
# Inserted chunk 489 from ABB.xlsx
# Inserted chunk 490 from ABB.xlsx
# Inserted chunk 491 from ABB.xlsx
# Inserted chunk 492 from ABB.xlsx
# Inserted chunk 493 from ABB.xlsx
# Inserted chunk 494 from ABB.xlsx
# Inserted chunk 495 from ABB.xlsx
# Inserted chunk 496 from ABB.xlsx
# Inserted chunk 497 from ABB.xlsx
# Inserted chunk 498 from ABB.xlsx
# Inserted chunk 499 from ABB.xlsx
# Inserted chunk 500 from ABB.xlsx
# Inserted chunk 501 from ABB.xlsx
# Inserted chunk 502 from ABB.xlsx
# Inserted chunk 503 from ABB.xlsx
# Inserted chunk 504 from ABB.xlsx
# Inserted chunk 505 from ABB.xlsx
# Inserted chunk 506 from ABB.xlsx
# Inserted chunk 507 from ABB.xlsx
# Inserted chunk 508 from ABB.xlsx
# Inserted chunk 509 from ABB.xlsx
# Inserted chunk 510 from ABB.xlsx
# Inserted chunk 511 from ABB.xlsx
# Inserted chunk 512 from ABB.xlsx
# Inserted chunk 513 from ABB.xlsx
# Inserted chunk 514 from ABB.xlsx
# Inserted chunk 515 from ABB.xlsx
# Inserted chunk 516 from ABB.xlsx
# Inserted chunk 517 from ABB.xlsx
# Inserted chunk 518 from ABB.xlsx
# Inserted chunk 519 from ABB.xlsx
# Inserted chunk 520 from ABB.xlsx
# Inserted chunk 521 from ABB.xlsx
# Inserted chunk 522 from ABB.xlsx
# Inserted chunk 523 from ABB.xlsx
# Inserted chunk 524 from ABB.xlsx
# Inserted chunk 525 from ABB.xlsx
# Inserted chunk 526 from ABB.xlsx
# Inserted chunk 527 from ABB.xlsx
# Inserted chunk 528 from ABB.xlsx
# Inserted chunk 529 from ABB.xlsx
# Inserted chunk 530 from ABB.xlsx
# Inserted chunk 531 from ABB.xlsx
# Inserted chunk 532 from ABB.xlsx
# Inserted chunk 533 from ABB.xlsx
# Inserted chunk 534 from ABB.xlsx
# Inserted chunk 535 from ABB.xlsx
# Inserted chunk 536 from ABB.xlsx
# Inserted chunk 537 from ABB.xlsx
# Inserted chunk 538 from ABB.xlsx
# Inserted chunk 539 from ABB.xlsx
# Inserted chunk 540 from ABB.xlsx
# Inserted chunk 541 from ABB.xlsx
# Inserted chunk 542 from ABB.xlsx
# Inserted chunk 543 from ABB.xlsx
# Inserted chunk 544 from ABB.xlsx
# Inserted chunk 545 from ABB.xlsx
# Inserted chunk 546 from ABB.xlsx
# Inserted chunk 547 from ABB.xlsx
# Inserted chunk 548 from ABB.xlsx
# Inserted chunk 549 from ABB.xlsx
# Inserted chunk 550 from ABB.xlsx
# Inserted chunk 551 from ABB.xlsx
# Inserted chunk 552 from ABB.xlsx
# Inserted chunk 553 from ABB.xlsx
# Inserted chunk 554 from ABB.xlsx
# Inserted chunk 555 from ABB.xlsx
# Inserted chunk 556 from ABB.xlsx
# Inserted chunk 557 from ABB.xlsx
# Inserted chunk 558 from ABB.xlsx
# Inserted chunk 559 from ABB.xlsx
# Inserted chunk 560 from ABB.xlsx
# Inserted chunk 561 from ABB.xlsx
# Inserted chunk 562 from ABB.xlsx
# Inserted chunk 563 from ABB.xlsx
# Inserted chunk 564 from ABB.xlsx
# Inserted chunk 565 from ABB.xlsx
# Inserted chunk 566 from ABB.xlsx
# Inserted chunk 567 from ABB.xlsx
# Inserted chunk 568 from ABB.xlsx
# Inserted chunk 569 from ABB.xlsx
# Inserted chunk 570 from ABB.xlsx
# Inserted chunk 571 from ABB.xlsx
# Inserted chunk 572 from ABB.xlsx
# Inserted chunk 573 from ABB.xlsx
# Inserted chunk 574 from ABB.xlsx
# Inserted chunk 575 from ABB.xlsx
# Inserted chunk 576 from ABB.xlsx
# Inserted chunk 577 from ABB.xlsx
# Inserted chunk 578 from ABB.xlsx
# Inserted chunk 579 from ABB.xlsx
# Inserted chunk 580 from ABB.xlsx
# Inserted chunk 581 from ABB.xlsx
# Inserted chunk 582 from ABB.xlsx
# Inserted chunk 583 from ABB.xlsx
# Inserted chunk 584 from ABB.xlsx
# Inserted chunk 585 from ABB.xlsx
# Inserted chunk 586 from ABB.xlsx
# Inserted chunk 587 from ABB.xlsx
# Inserted chunk 588 from ABB.xlsx
# Inserted chunk 589 from ABB.xlsx
# Inserted chunk 590 from ABB.xlsx
# Inserted chunk 591 from ABB.xlsx
# Inserted chunk 592 from ABB.xlsx
# Inserted chunk 593 from ABB.xlsx
# Inserted chunk 594 from ABB.xlsx
# Inserted chunk 595 from ABB.xlsx
# Inserted chunk 596 from ABB.xlsx
# Inserted chunk 597 from ABB.xlsx
# Inserted chunk 598 from ABB.xlsx
# Inserted chunk 599 from ABB.xlsx
# Inserted chunk 600 from ABB.xlsx
# Inserted chunk 601 from ABB.xlsx
# Inserted chunk 602 from ABB.xlsx
# Inserted chunk 603 from ABB.xlsx
# Inserted chunk 604 from ABB.xlsx
# Inserted chunk 605 from ABB.xlsx
# Inserted chunk 606 from ABB.xlsx
# Inserted chunk 607 from ABB.xlsx
# Inserted chunk 608 from ABB.xlsx
# Inserted chunk 609 from ABB.xlsx
# Inserted chunk 610 from ABB.xlsx
# Inserted chunk 611 from ABB.xlsx
# Inserted chunk 612 from ABB.xlsx
# Inserted chunk 613 from ABB.xlsx
# Inserted chunk 614 from ABB.xlsx
# Inserted chunk 615 from ABB.xlsx
# Inserted chunk 616 from ABB.xlsx
# Inserted chunk 617 from ABB.xlsx
# Inserted chunk 618 from ABB.xlsx
# Inserted chunk 619 from ABB.xlsx
# Inserted chunk 620 from ABB.xlsx
# Inserted chunk 621 from ABB.xlsx
# Inserted chunk 622 from ABB.xlsx
# Inserted chunk 623 from ABB.xlsx
# Inserted chunk 624 from ABB.xlsx
# Inserted chunk 625 from ABB.xlsx
# Inserted chunk 626 from ABB.xlsx
# Inserted chunk 627 from ABB.xlsx
# Inserted chunk 628 from ABB.xlsx
# Inserted chunk 629 from ABB.xlsx
# Inserted chunk 630 from ABB.xlsx
# Inserted chunk 631 from ABB.xlsx
# Inserted chunk 632 from ABB.xlsx
# Inserted chunk 633 from ABB.xlsx
# Inserted chunk 634 from ABB.xlsx
# Inserted chunk 635 from ABB.xlsx
# Inserted chunk 636 from ABB.xlsx
# Inserted chunk 637 from ABB.xlsx
# Inserted chunk 638 from ABB.xlsx
# Inserted chunk 639 from ABB.xlsx
# Inserted chunk 640 from ABB.xlsx
# Inserted chunk 641 from ABB.xlsx
# Inserted chunk 642 from ABB.xlsx
# Inserted chunk 643 from ABB.xlsx
# Inserted chunk 644 from ABB.xlsx
# Inserted chunk 645 from ABB.xlsx
# Inserted chunk 646 from ABB.xlsx
# Inserted chunk 647 from ABB.xlsx
# Inserted chunk 648 from ABB.xlsx
# Inserted chunk 649 from ABB.xlsx
# Inserted chunk 650 from ABB.xlsx
# Inserted chunk 651 from ABB.xlsx
# Inserted chunk 652 from ABB.xlsx
# Inserted chunk 653 from ABB.xlsx
# Inserted chunk 654 from ABB.xlsx
# Inserted chunk 655 from ABB.xlsx
# Inserted chunk 656 from ABB.xlsx
# Inserted chunk 657 from ABB.xlsx
# Inserted chunk 658 from ABB.xlsx
# Inserted chunk 659 from ABB.xlsx
# Inserted chunk 660 from ABB.xlsx
# Inserted chunk 661 from ABB.xlsx
# Inserted chunk 662 from ABB.xlsx
# Inserted chunk 663 from ABB.xlsx
# Inserted chunk 664 from ABB.xlsx
# Inserted chunk 665 from ABB.xlsx
# Inserted chunk 666 from ABB.xlsx
# Inserted chunk 667 from ABB.xlsx
# Inserted chunk 668 from ABB.xlsx
# Inserted chunk 669 from ABB.xlsx
# Inserted chunk 670 from ABB.xlsx
# Inserted chunk 671 from ABB.xlsx
# Inserted chunk 672 from ABB.xlsx
# Inserted chunk 673 from ABB.xlsx
# Inserted chunk 674 from ABB.xlsx
# Inserted chunk 675 from ABB.xlsx
# Inserted chunk 676 from ABB.xlsx
# Inserted chunk 677 from ABB.xlsx
# Inserted chunk 678 from ABB.xlsx
# Inserted chunk 679 from ABB.xlsx
# Inserted chunk 680 from ABB.xlsx
# Inserted chunk 681 from ABB.xlsx
# Inserted chunk 682 from ABB.xlsx
# Inserted chunk 683 from ABB.xlsx
# Inserted chunk 684 from ABB.xlsx
# Inserted chunk 685 from ABB.xlsx
# Inserted chunk 686 from ABB.xlsx
# Inserted chunk 687 from ABB.xlsx
# Inserted chunk 688 from ABB.xlsx
# Inserted chunk 689 from ABB.xlsx
# Inserted chunk 690 from ABB.xlsx
# Inserted chunk 691 from ABB.xlsx
# Inserted chunk 692 from ABB.xlsx
# Inserted chunk 693 from ABB.xlsx
# Inserted chunk 694 from ABB.xlsx
# Inserted chunk 695 from ABB.xlsx
# Inserted chunk 696 from ABB.xlsx
# Inserted chunk 697 from ABB.xlsx
# Inserted chunk 698 from ABB.xlsx
# Inserted chunk 699 from ABB.xlsx
# Inserted chunk 700 from ABB.xlsx
# Inserted chunk 701 from ABB.xlsx
# Inserted chunk 702 from ABB.xlsx
# Inserted chunk 703 from ABB.xlsx
# Inserted chunk 704 from ABB.xlsx
# Inserted chunk 705 from ABB.xlsx
# Inserted chunk 706 from ABB.xlsx
# Inserted chunk 707 from ABB.xlsx
# Inserted chunk 708 from ABB.xlsx
# Inserted chunk 709 from ABB.xlsx
# Inserted chunk 710 from ABB.xlsx
# Inserted chunk 711 from ABB.xlsx
# Inserted chunk 712 from ABB.xlsx
# Inserted chunk 713 from ABB.xlsx
# Inserted chunk 714 from ABB.xlsx
# Inserted chunk 715 from ABB.xlsx
# Inserted chunk 716 from ABB.xlsx
# Inserted chunk 717 from ABB.xlsx
# Inserted chunk 718 from ABB.xlsx
# Inserted chunk 719 from ABB.xlsx
# Inserted chunk 720 from ABB.xlsx
# Inserted chunk 721 from ABB.xlsx
# Inserted chunk 722 from ABB.xlsx
# Inserted chunk 723 from ABB.xlsx
# Inserted chunk 724 from ABB.xlsx
# Inserted chunk 725 from ABB.xlsx
# Inserted chunk 726 from ABB.xlsx
# Inserted chunk 727 from ABB.xlsx
# Inserted chunk 728 from ABB.xlsx
# Inserted chunk 729 from ABB.xlsx
# Inserted chunk 730 from ABB.xlsx
# Inserted chunk 731 from ABB.xlsx
# Inserted chunk 732 from ABB.xlsx
# Inserted chunk 733 from ABB.xlsx
# Inserted chunk 734 from ABB.xlsx
# Inserted chunk 735 from ABB.xlsx
# Inserted chunk 736 from ABB.xlsx
# Inserted chunk 737 from ABB.xlsx
# Inserted chunk 738 from ABB.xlsx
# Inserted chunk 739 from ABB.xlsx
# Inserted chunk 740 from ABB.xlsx
# Inserted chunk 741 from ABB.xlsx
# Inserted chunk 742 from ABB.xlsx
# Inserted chunk 743 from ABB.xlsx
# Inserted chunk 744 from ABB.xlsx
# Inserted chunk 745 from ABB.xlsx
# Inserted chunk 746 from ABB.xlsx
# Inserted chunk 747 from ABB.xlsx
# Inserted chunk 748 from ABB.xlsx
# Inserted chunk 749 from ABB.xlsx
# Inserted chunk 750 from ABB.xlsx
# Inserted chunk 751 from ABB.xlsx
# Inserted chunk 752 from ABB.xlsx
# Inserted chunk 753 from ABB.xlsx
# Inserted chunk 754 from ABB.xlsx
# Inserted chunk 755 from ABB.xlsx
# Inserted chunk 756 from ABB.xlsx
# Inserted chunk 757 from ABB.xlsx
# Inserted chunk 758 from ABB.xlsx
# Inserted chunk 759 from ABB.xlsx
# Inserted chunk 760 from ABB.xlsx
# Inserted chunk 761 from ABB.xlsx
# Inserted chunk 762 from ABB.xlsx
# Inserted chunk 763 from ABB.xlsx
# Inserted chunk 764 from ABB.xlsx
# Inserted chunk 765 from ABB.xlsx
# Inserted chunk 766 from ABB.xlsx
# Inserted chunk 767 from ABB.xlsx
# Inserted chunk 768 from ABB.xlsx
# Inserted chunk 769 from ABB.xlsx
# Inserted chunk 770 from ABB.xlsx
# Inserted chunk 771 from ABB.xlsx
# Inserted chunk 772 from ABB.xlsx
# Inserted chunk 773 from ABB.xlsx
# Inserted chunk 774 from ABB.xlsx
# Inserted chunk 775 from ABB.xlsx
# Inserted chunk 776 from ABB.xlsx
# Inserted chunk 777 from ABB.xlsx
# Inserted chunk 778 from ABB.xlsx
# Inserted chunk 779 from ABB.xlsx
# Inserted chunk 780 from ABB.xlsx
# Inserted chunk 781 from ABB.xlsx
# Inserted chunk 782 from ABB.xlsx
# Inserted chunk 783 from ABB.xlsx
# Inserted chunk 784 from ABB.xlsx
# Inserted chunk 785 from ABB.xlsx
# Inserted chunk 786 from ABB.xlsx
# Inserted chunk 787 from ABB.xlsx
# Inserted chunk 788 from ABB.xlsx
# Inserted chunk 789 from ABB.xlsx
# Inserted chunk 790 from ABB.xlsx
# Inserted chunk 791 from ABB.xlsx
# Inserted chunk 792 from ABB.xlsx
# Inserted chunk 793 from ABB.xlsx
# Inserted chunk 794 from ABB.xlsx
# Inserted chunk 795 from ABB.xlsx
# Inserted chunk 796 from ABB.xlsx
# Inserted chunk 797 from ABB.xlsx
# Inserted chunk 798 from ABB.xlsx
# Inserted chunk 799 from ABB.xlsx
# Inserted chunk 800 from ABB.xlsx
# Inserted chunk 801 from ABB.xlsx
# Inserted chunk 802 from ABB.xlsx
# Inserted chunk 803 from ABB.xlsx
# Inserted chunk 804 from ABB.xlsx
# Inserted chunk 805 from ABB.xlsx
# Inserted chunk 806 from ABB.xlsx
# Inserted chunk 807 from ABB.xlsx
# Inserted chunk 808 from ABB.xlsx
# Inserted chunk 809 from ABB.xlsx
# Inserted chunk 810 from ABB.xlsx
# Inserted chunk 811 from ABB.xlsx
# Inserted chunk 812 from ABB.xlsx
# Inserted chunk 813 from ABB.xlsx
# Inserted chunk 814 from ABB.xlsx
# Inserted chunk 815 from ABB.xlsx
# Inserted chunk 816 from ABB.xlsx
# Inserted chunk 817 from ABB.xlsx
# Inserted chunk 818 from ABB.xlsx
# Inserted chunk 819 from ABB.xlsx
# Inserted chunk 820 from ABB.xlsx
# Inserted chunk 821 from ABB.xlsx
# Inserted chunk 822 from ABB.xlsx
# Inserted chunk 823 from ABB.xlsx
# Inserted chunk 824 from ABB.xlsx
# Inserted chunk 825 from ABB.xlsx
# Inserted chunk 826 from ABB.xlsx
# Inserted chunk 827 from ABB.xlsx
# Inserted chunk 828 from ABB.xlsx
# Inserted chunk 829 from ABB.xlsx
# Inserted chunk 830 from ABB.xlsx
# Inserted chunk 831 from ABB.xlsx
# Inserted chunk 832 from ABB.xlsx
# Inserted chunk 833 from ABB.xlsx
# Inserted chunk 834 from ABB.xlsx
# Inserted chunk 835 from ABB.xlsx
# Inserted chunk 836 from ABB.xlsx
# Inserted chunk 837 from ABB.xlsx
# Inserted chunk 838 from ABB.xlsx
# Inserted chunk 839 from ABB.xlsx
# Inserted chunk 840 from ABB.xlsx
# Inserted chunk 841 from ABB.xlsx
# Inserted chunk 842 from ABB.xlsx
# Inserted chunk 843 from ABB.xlsx
# Inserted chunk 844 from ABB.xlsx
# Inserted chunk 845 from ABB.xlsx
# Inserted chunk 846 from ABB.xlsx
# Inserted chunk 847 from ABB.xlsx
# Inserted chunk 848 from ABB.xlsx
# Inserted chunk 849 from ABB.xlsx
# Inserted chunk 850 from ABB.xlsx
# Inserted chunk 851 from ABB.xlsx
# Inserted chunk 852 from ABB.xlsx
# Inserted chunk 853 from ABB.xlsx
# Inserted chunk 854 from ABB.xlsx
# Inserted chunk 855 from ABB.xlsx
# Inserted chunk 856 from ABB.xlsx
# Inserted chunk 857 from ABB.xlsx
# Inserted chunk 858 from ABB.xlsx
# Inserted chunk 859 from ABB.xlsx
# Inserted chunk 860 from ABB.xlsx
# Inserted chunk 861 from ABB.xlsx
# Inserted chunk 862 from ABB.xlsx
# Inserted chunk 863 from ABB.xlsx
# Inserted chunk 864 from ABB.xlsx
# Inserted chunk 865 from ABB.xlsx
# Inserted chunk 866 from ABB.xlsx
# Inserted chunk 867 from ABB.xlsx
# Inserted chunk 868 from ABB.xlsx
# Inserted chunk 869 from ABB.xlsx
# Inserted chunk 870 from ABB.xlsx
# Inserted chunk 871 from ABB.xlsx
# Inserted chunk 872 from ABB.xlsx
# Inserted chunk 873 from ABB.xlsx
# Inserted chunk 874 from ABB.xlsx
# Inserted chunk 875 from ABB.xlsx
# Inserted chunk 876 from ABB.xlsx
